# %% [markdown]
# ## Pre processing data

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns
sns.set(style="ticks", color_codes=True)

import warnings
warnings.filterwarnings('ignore')

from numpy import random

# %%
file = 'data/002_intermediate_data/raw_renamed_data.csv'
raw_data = pd.read_csv(file, encoding='latin-1')
print('shape raw:', raw_data.shape)
raw_data.head(3)
# Out:
# shape raw: (603, 15)
#    id                 title  artist        top genre  year  bpm  nrgy  dnce  \
# 0   1      Hey, Soul Sister   Train       neo mellow  2010   97    89    67
# 1   2  Love The Way You Lie  Eminem  detroit hip hop  2010   87    93    75
# 2   3               TiK ToK   Kesha        dance pop  2010  120    84    76
#
#    dB  live  val  dur  acous  spch  pop
# 0  -4     8   80  217     19     4   83
# 1  -5    52   64  263     24    23   82
# 2  -3    29   71  200     10    14   80

# %% [markdown]
# ## Classes by `top genre`: balance

# %%
raw_data['top genre'].nunique()
# Out:
# 50

# %%
songs_by_genre = raw_data.groupby(by='top genre', as_index=False)['id'].agg({'songs': 'count'}) \
        .sort_values('songs', ascending=False) \
        .reset_index(drop=True)
songs_by_genre.rename(columns={'top genre': 'genre'}, inplace=True)
songs_by_genre
# Out:
#                         genre  songs
# 0                   dance pop    327
# 1                         pop     60
# 2                canadian pop     34
# 3                    boy band     15
# 4               barbadian pop     15
# 5                  electropop     13
# 6                british soul     11
# 7                    big room     10
# 8   canadian contemporary r&b      9
# 9                  neo mellow      9
# 10                    art pop      8
# 11                    hip pop      6
# 12                 complextro      6
# 13           australian dance      6
# 14             australian pop      5
# 15                atl hip hop      5
# 16                        edm      5
# 17             permanent wave      4
# 18                    hip hop      4
# 19                      latin      4
# 20              colombian pop      3
# 21             tropical house      3
# 22               acoustic pop      2
# 23                   folk-pop      2
# 24                    brostep      2
# 25           canadian hip hop      2
# 26                baroque pop      2
# 27            detroit hip hop      2
# 28                  downtempo      2
# 29                  candy pop      2
# 30                    electro      2
# 31                  indie pop      2
# 32            electronic trap      2
# 33                belgian edm      2
# 34                escape room      2
# 35               moroccan pop      1
# 36               metropopolis      1
# 37         australian hip hop      1
# 38            alternative r&b      1
# 39    irish singer-songwriter      1
# 40                chicago rap      1
# 41                      house      1
# 42                  hollywood      1
# 43                celtic rock      1
# 44             canadian latin      1
# 45              electro house      1
# 46                 danish pop      1
# 47               alaska indie      1
# 48       contemporary country      1
# 49           french indie pop      1

# %%
# Minumum 5 songs genres
songs_by_genre[songs_by_genre['songs'] >= 5]
# Out:
#                         genre  songs
# 0                   dance pop    327
# 1                         pop     60
# 2                canadian pop     34
# 3                    boy band     15
# 4               barbadian pop     15
# 5                  electropop     13
# 6                british soul     11
# 7                    big room     10
# 8   canadian contemporary r&b      9
# 9                  neo mellow      9
# 10                    art pop      8
# 11                    hip pop      6
# 12                 complextro      6
# 13           australian dance      6
# 14             australian pop      5
# 15                atl hip hop      5
# 16                        edm      5

# %% [markdown]
# ## Group by super genres
#
# The name at the end of the genre can indicate a super genre.

# %%
# Pop super genre
pop = songs_by_genre['genre'].str.endswith('pop')
print(f'Sum of genres: {songs_by_genre.genre[pop].count()}')
print(f'Sum of songs: {sum(songs_by_genre.songs[pop])}')
songs_by_genre[pop]
# Out:
# Sum of genres: 17
# Sum of songs: 484
#                genre  songs
# 0          dance pop    327
# 1                pop     60
# 2       canadian pop     34
# 4      barbadian pop     15
# 5         electropop     13
# 10           art pop      8
# 11           hip pop      6
# 14    australian pop      5
# 20     colombian pop      3
# 22      acoustic pop      2
# 23          folk-pop      2
# 26       baroque pop      2
# 29         candy pop      2
# 31         indie pop      2
# 35      moroccan pop      1
# 46        danish pop      1
# 49  french indie pop      1

# %%
# Hip hop super genre
hiphop = songs_by_genre['genre'].str.endswith('hip hop')
print(f'Sum of genres: {songs_by_genre.genre[hiphop].count()}')
print(f'Sum of songs: {sum(songs_by_genre.songs[hiphop])}')
songs_by_genre[hiphop]
# Out:
# Sum of genres: 5
# Sum of songs: 14
#                  genre  songs
# 15         atl hip hop      5
# 18             hip hop      4
# 25    canadian hip hop      2
# 27     detroit hip hop      2
# 37  australian hip hop      1

# %%
# Indie super genre
indie = songs_by_genre['genre'].str.endswith('indie')
print(f'Sum of genres: {songs_by_genre.genre[indie].count()}')
print(f'Sum of songs: {sum(songs_by_genre.songs[indie])}')
songs_by_genre[indie]
# Out:
# Sum of genres: 1
# Sum of songs: 1
#            genre  songs
# 47  alaska indie      1

# %%
# Rock super genre
rock = songs_by_genre['genre'].str.endswith('rock')
print(f'Sum of genres: {songs_by_genre.genre[rock].count()}')
print(f'Sum of songs: {sum(songs_by_genre.songs[rock])}')
songs_by_genre[rock]
# Out:
# Sum of genres: 1
# Sum of songs: 1
#           genre  songs
# 43  celtic rock      1

# %%
# Dance super genre
dance = songs_by_genre['genre'].str.endswith('dance')
print(f'Sum of genres: {songs_by_genre.genre[dance].count()}')
print(f'Sum of songs: {sum(songs_by_genre.songs[dance])}')
songs_by_genre[dance]
# Out:
# Sum of genres: 1
# Sum of songs: 6
#                genre  songs
# 13  australian dance      6

# %%
# getting all possible subgenres
last_genre_name = songs_by_genre.genre.str.split().apply(lambda x: x[-1])
last_genre_name.drop_duplicates().reset_index(drop=True)
# Out:
# 0                   pop
# 1                  band
# 2            electropop
# 3                  soul
# 4                  room
# 5                   r&b
# 6                mellow
# 7            complextro
# 8                 dance
# 9                   hop
# 10                  edm
# 11                 wave
# 12                latin
# 13                house
# 14             folk-pop
# 15              brostep
# 16            downtempo
# 17              electro
# 18                 trap
# 19         metropopolis
# 20    singer-songwriter
# 21                  rap
# 22            hollywood
# 23                 rock
# 24                indie
# 25              country
# Name: genre, dtype: object

# %% [markdown]
# > **Conclusion:** we can have half the number of genres if we get the super genre as proposed.

# %% [markdown]
# ## Using supergenre

# %%
songs_by_genre['supergenre'] = last_genre_name
songs_by_genre.head(10)
# Out:
#                        genre  songs  supergenre
# 0                  dance pop    327         pop
# 1                        pop     60         pop
# 2               canadian pop     34         pop
# 3                   boy band     15        band
# 4              barbadian pop     15         pop
# 5                 electropop     13  electropop
# 6               british soul     11        soul
# 7                   big room     10        room
# 8  canadian contemporary r&b      9         r&b
# 9                 neo mellow      9      mellow

# %%
songs_by_genre.groupby(by='supergenre', as_index=False)['songs'].agg({'songs': 'sum'}) \
        .sort_values('songs', ascending=False) \
        .reset_index(drop=True)
# Out:
#            supergenre  songs
# 0                 pop    469
# 1                band     15
# 2                 hop     14
# 3          electropop     13
# 4                room     12
# 5                soul     11
# 6                 r&b     10
# 7              mellow      9
# 8                 edm      7
# 9          complextro      6
# 10              dance      6
# 11              latin      5
# 12              house      5
# 13               wave      4
# 14            brostep      2
# 15           folk-pop      2
# 16            electro      2
# 17          downtempo      2
# 18               trap      2
# 19          hollywood      1
# 20       metropopolis      1
# 21                rap      1
# 22               rock      1
# 23  singer-songwriter      1
# 24            country      1
# 25              indie      1

# %% [markdown]
# #### Attention to
#
# `hip hop` -> name cannot be splitted.
#
# Some pop genres have a representative number of songs to remain as individual genres.
#
# * dance pop: 327
# * pop: 60
# * canadian pop: 34
# * barbadian pop: 15

# %% [markdown]
# ### Function to map genre to supergenre

# %%
def map_supergenre(genre: str) -> str:
    """Maps a genre with its supergenre considering special cases when the genre itself is returned.
    """
    exceptions = ['dance pop', 'pop', 'canadian pop', 'barbadian pop']
    if genre in exceptions:
        return genre
    elif genre.endswith('hip hop'):
        return 'hip hop'
    else:
        return genre.split()[-1]
    
[map_supergenre(x) for x in ['dance pop', 'pop', 'hip hop', 'new hip hop', 'indie pop', 
                             'australian pop','colombian pop','acoustic pop','folk-pop']]
# Out:
# ['dance pop',
#  'pop',
#  'hip hop',
#  'hip hop',
#  'pop',
#  'pop',
#  'pop',
#  'pop',
#  'folk-pop']

# %%
# supergenre adjusted
songs_by_genre['supergenre_adj'] = songs_by_genre.genre.apply(map_supergenre)
songs_by_genre.head(15)
# Out:
#                         genre  songs  supergenre supergenre_adj
# 0                   dance pop    327         pop      dance pop
# 1                         pop     60         pop            pop
# 2                canadian pop     34         pop   canadian pop
# 3                    boy band     15        band           band
# 4               barbadian pop     15         pop  barbadian pop
# 5                  electropop     13  electropop     electropop
# 6                british soul     11        soul           soul
# 7                    big room     10        room           room
# 8   canadian contemporary r&b      9         r&b            r&b
# 9                  neo mellow      9      mellow         mellow
# 10                    art pop      8         pop            pop
# 11                    hip pop      6         pop            pop
# 12                 complextro      6  complextro     complextro
# 13           australian dance      6       dance          dance
# 14             australian pop      5         pop            pop

# %%
songs_by_supergenre = songs_by_genre.groupby(by='supergenre_adj', as_index=False)['songs'].agg({'songs': 'sum'}) \
        .sort_values('songs', ascending=False) \
        .reset_index(drop=True)
songs_by_supergenre
# Out:
#        supergenre_adj  songs
# 0           dance pop    327
# 1                 pop     93
# 2        canadian pop     34
# 3                band     15
# 4       barbadian pop     15
# 5             hip hop     14
# 6          electropop     13
# 7                room     12
# 8                soul     11
# 9                 r&b     10
# 10             mellow      9
# 11                edm      7
# 12         complextro      6
# 13              dance      6
# 14              latin      5
# 15              house      5
# 16               wave      4
# 17           folk-pop      2
# 18            electro      2
# 19          downtempo      2
# 20            brostep      2
# 21               trap      2
# 22              indie      1
# 23       metropopolis      1
# 24                rap      1
# 25               rock      1
# 26            country      1
# 27  singer-songwriter      1
# 28          hollywood      1

# %% [markdown]
# ### Criteria for selecting songs of each class
#
# 1. Only genres with at least 5 songs will be allowed.
# 2. For genres with more than 15 songs, only 15 will be chosen randomly.

# %% [markdown]
# #### First criterion

# %%
minimum_songs = songs_by_supergenre.supergenre_adj[songs_by_supergenre.songs >= 5]
minimum_songs
# Out:
# 0         dance pop
# 1               pop
# 2      canadian pop
# 3              band
# 4     barbadian pop
# 5           hip hop
# 6        electropop
# 7              room
# 8              soul
# 9               r&b
# 10           mellow
# 11              edm
# 12       complextro
# 13            dance
# 14            latin
# 15            house
# Name: supergenre_adj, dtype: object

# %%
raw_data.head()
# Out:
#    id                 title      artist        top genre  year  bpm  nrgy  \
# 0   1      Hey, Soul Sister       Train       neo mellow  2010   97    89
# 1   2  Love The Way You Lie      Eminem  detroit hip hop  2010   87    93
# 2   3               TiK ToK       Kesha        dance pop  2010  120    84
# 3   4           Bad Romance   Lady Gaga        dance pop  2010  119    92
# 4   5  Just the Way You Are  Bruno Mars              pop  2010  109    84
#
#    dnce  dB  live  val  dur  acous  spch  pop
# 0    67  -4     8   80  217     19     4   83
# 1    75  -5    52   64  263     24    23   82
# 2    76  -3    29   71  200     10    14   80
# 3    70  -4     8   71  295      0     4   79
# 4    64  -5     9   43  221      2     4   78

# %%
raw_data.rename(columns={'top genre': 'genre'}, inplace=True)
raw_data.head()
# Out:
#    id                 title      artist            genre  year  bpm  nrgy  \
# 0   1      Hey, Soul Sister       Train       neo mellow  2010   97    89
# 1   2  Love The Way You Lie      Eminem  detroit hip hop  2010   87    93
# 2   3               TiK ToK       Kesha        dance pop  2010  120    84
# 3   4           Bad Romance   Lady Gaga        dance pop  2010  119    92
# 4   5  Just the Way You Are  Bruno Mars              pop  2010  109    84
#
#    dnce  dB  live  val  dur  acous  spch  pop
# 0    67  -4     8   80  217     19     4   83
# 1    75  -5    52   64  263     24    23   82
# 2    76  -3    29   71  200     10    14   80
# 3    70  -4     8   71  295      0     4   79
# 4    64  -5     9   43  221      2     4   78

# %%
raw_data['supergenre'] = raw_data.genre.apply(map_supergenre)
raw_data.head()
# Out:
#    id                 title      artist            genre  year  bpm  nrgy  \
# 0   1      Hey, Soul Sister       Train       neo mellow  2010   97    89
# 1   2  Love The Way You Lie      Eminem  detroit hip hop  2010   87    93
# 2   3               TiK ToK       Kesha        dance pop  2010  120    84
# 3   4           Bad Romance   Lady Gaga        dance pop  2010  119    92
# 4   5  Just the Way You Are  Bruno Mars              pop  2010  109    84
#
#    dnce  dB  live  val  dur  acous  spch  pop supergenre
# 0    67  -4     8   80  217     19     4   83     mellow
# 1    75  -5    52   64  263     24    23   82    hip hop
# 2    76  -3    29   71  200     10    14   80  dance pop
# 3    70  -4     8   71  295      0     4   79  dance pop
# 4    64  -5     9   43  221      2     4   78        pop

# %%
print('raw - shape:', raw_data.shape)
print('raw - unique supergenre:', raw_data.supergenre.nunique())
# Out:
# raw - shape: (603, 16)
# raw - unique supergenre: 29

# %%
minimum_crit = raw_data['supergenre'].isin(list(minimum_songs)) # supergenre has at least 5 songs
preprocessed_data = raw_data[minimum_crit]

print('preprocessed - shape:', preprocessed_data.shape)
print('preprocessed - unique supergenre:', preprocessed_data.supergenre.nunique())
preprocessed_data.supergenre.drop_duplicates()
# Out:
# preprocessed - shape: (582, 16)
# preprocessed - unique supergenre: 16
# 0             mellow
# 1            hip hop
# 2          dance pop
# 4                pop
# 5       canadian pop
# 9      barbadian pop
# 50              room
# 52              soul
# 108             band
# 154       complextro
# 225            house
# 240       electropop
# 252            dance
# 270              r&b
# 334              edm
# 440            latin
# Name: supergenre, dtype: object

# %%
preprocessed_data.head()
# Out:
#    id                 title      artist            genre  year  bpm  nrgy  \
# 0   1      Hey, Soul Sister       Train       neo mellow  2010   97    89
# 1   2  Love The Way You Lie      Eminem  detroit hip hop  2010   87    93
# 2   3               TiK ToK       Kesha        dance pop  2010  120    84
# 3   4           Bad Romance   Lady Gaga        dance pop  2010  119    92
# 4   5  Just the Way You Are  Bruno Mars              pop  2010  109    84
#
#    dnce  dB  live  val  dur  acous  spch  pop supergenre
# 0    67  -4     8   80  217     19     4   83     mellow
# 1    75  -5    52   64  263     24    23   82    hip hop
# 2    76  -3    29   71  200     10    14   80  dance pop
# 3    70  -4     8   71  295      0     4   79  dance pop
# 4    64  -5     9   43  221      2     4   78        pop

# %% [markdown]
# #### Second criterion

# %%
maximum_songs = songs_by_supergenre[songs_by_supergenre.songs > 15]
maximum_songs
# Out:
#   supergenre_adj  songs
# 0      dance pop    327
# 1            pop     93
# 2   canadian pop     34

# %%
#from numpy.random import default_rng

rng = random.default_rng()
numbers = rng.choice(20, size=10, replace=False)
print(numbers)
# Out:
# [19  8  9  6 12 15 18  3  1 11]

# %%
# non repeating numbers -> using Numpy's default_rng() and choice(replace=False)
rng = random.default_rng()
nsongs = 15

value = int(maximum_songs.songs[maximum_songs.supergenre_adj == 'dance pop'])
rand_dance_pop = rng.choice(327, size=nsongs, replace=False)
print(value)
print(rand_dance_pop)

value = int(maximum_songs.songs[maximum_songs.supergenre_adj == 'pop'])
rand_pop = rng.choice(value, size=nsongs, replace=False)
print(value)
print(rand_pop)

value = int(maximum_songs.songs[maximum_songs.supergenre_adj == 'canadian pop'])
rand_canadian_pop = rng.choice(value, size=nsongs, replace=False)
print(value)
print(rand_canadian_pop)
# Out:
# 327
# [126 212 259 200  26 257 233 100  99  55 296 319 250 248 193]
# 93
# [55  3 53 33  2 82 39 83 15 74 10 13 48 46 37]
# 34
# [20 24 21 26 14 22  8  7 16 10 28 19 12 25 11]

# %%
list(rand_dance_pop)
# Out:
# [126, 212, 259, 200, 26, 257, 233, 100, 99, 55, 296, 319, 250, 248, 193]

# %%
ids = list(preprocessed_data[preprocessed_data.supergenre == 'dance pop']['id'])
print(len(ids))
selected_ids = [ids[r] for r in list(rand_dance_pop)]
print(selected_ids)

final_selected_ids = []
final_selected_ids.extend(selected_ids)
print(final_selected_ids)
# Out:
# 327
# [213, 381, 467, 359, 41, 461, 411, 172, 171, 87, 534, 572, 440, 438, 349]
# [213, 381, 467, 359, 41, 461, 411, 172, 171, 87, 534, 572, 440, 438, 349]

# %%
ids = list(preprocessed_data[preprocessed_data.supergenre == 'pop']['id'])
print(len(ids))
selected_ids = [ids[r] for r in list(rand_pop)]
print(selected_ids)

final_selected_ids.extend(selected_ids)
print(final_selected_ids)
# Out:
# 93
# [293, 22, 275, 175, 12, 570, 216, 571, 69, 511, 44, 60, 259, 235, 212]
# [213, 381, 467, 359, 41, 461, 411, 172, 171, 87, 534, 572, 440, 438, 349, 293, 22, 275, 175, 12, 570, 216, 571, 69, 511, 44, 60, 259, 235, 212]

# %%
ids = list(preprocessed_data[preprocessed_data.supergenre == 'canadian pop']['id'])
print(len(ids))
selected_ids = [ids[r] for r in list(rand_canadian_pop)]
print(selected_ids)

final_selected_ids.extend(selected_ids)
print(final_selected_ids)
# Out:
# 34
# [397, 434, 412, 451, 321, 416, 276, 272, 331, 281, 513, 379, 315, 447, 302]
# [213, 381, 467, 359, 41, 461, 411, 172, 171, 87, 534, 572, 440, 438, 349, 293, 22, 275, 175, 12, 570, 216, 571, 69, 511, 44, 60, 259, 235, 212, 397, 434, 412, 451, 321, 416, 276, 272, 331, 281, 513, 379, 315, 447, 302]

# %%
len(final_selected_ids)
# Out:
# 45

# %%
maximum_data = preprocessed_data[preprocessed_data['id'].isin(final_selected_ids)].reset_index(drop=True)
print('shape:', maximum_data.shape)
maximum_data
# Out:
# shape: (45, 16)
#      id                                              title  \
# 0    12                                          Marry You
# 1    22                               Whataya Want from Me
# 2    41  Something's Got A Hold On Me - Burlesque Origi...
# 3    44                                               Loca
# 4    60                                            Grenade
# 5    69                                          Price Tag
# 6    87                                    Marry The Night
# 7   171           If I Lose Myself - Alesso vs OneRepublic
# 8   172                                            The Way
# 9   175                       I Love It (feat. Charli XCX)
# 10  212                                       Stay With Me
# 11  213                                             Summer
# 12  216                                       Shake It Off
# 13  235                                        Young Girls
# 14  259  Boom Clap - From the Motion Picture Das Schick...
# 15  272                                      Love Yourself
# 16  275                                              Sugar
# 17  276                                              Sorry
# 18  281                                           Stitches
# 19  293                                              Don't
# 20  302                                            Company
# 21  315                                      I'll Show You
# 22  321                                  I Really Like You
# 23  331                                      Mark My Words
# 24  349                       Don't Be so Hard on Yourself
# 25  359                                     Spark The Fire
# 26  379                                           Stitches
# 27  381                I Took A Pill In Ibiza - Seeb Remix
# 28  397                                            Company
# 29  411                                           Body Say
# 30  412                                    Don't Be A Fool
# 31  416                                   Run Away With Me
# 32  434                                             Higher
# 33  438                                        Little Lies
# 34  440                                          BURNITUP!
# 35  447                                   Treat You Better
# 36  451                                              Mercy
# 37  461                                            Praying
# 38  467                                               Mama
# 39  511                                          I Like It
# 40  513                    There's Nothing Holdin' Me Back
# 41  534                                          My My My!
# 42  570                 ...Ready For It? - BloodPop® Remix
# 43  571                                 Drip (feat. Migos)
# 44  572                   Tell Me You Love Me - NOTD Remix
#
#                 artist           genre  year  bpm  nrgy  dnce  dB  live  val  \
# 0           Bruno Mars             pop  2010  145    83    62  -5    10   48
# 1         Adam Lambert  australian pop  2010  186    68    44  -5     6   45
# 2   Christina Aguilera       dance pop  2010  150    85    51  -4    12   72
# 3              Shakira   colombian pop  2010  112    87    80  -4     9   85
# 4           Bruno Mars             pop  2011  110    56    71  -7    12   23
# 5             Jessie J  australian pop  2011  175    83    64  -4    27   68
# 6            Lady Gaga       dance pop  2011  131    88    61  -4    46   38
# 7          OneRepublic       dance pop  2013  126    75    52  -6    14   16
# 8        Ariana Grande       dance pop  2013   82    88    65  -3     8   86
# 9            Icona Pop       candy pop  2013  126    91    71  -3    15   82
# 10           Sam Smith             pop  2014   84    42    42  -6    11   18
# 11       Calvin Harris       dance pop  2014  128    86    60  -4    14   74
# 12        Taylor Swift             pop  2014  160    80    65  -5    33   94
# 13          Bruno Mars             pop  2014  126    75    56  -5    21   50
# 14          Charli XCX       candy pop  2014   92    81    68  -4    34   64
# 15       Justin Bieber    canadian pop  2015  100    38    61 -10    28   52
# 16            Maroon 5             pop  2015  120    79    75  -7     9   88
# 17       Justin Bieber    canadian pop  2015  100    76    65  -4    30   41
# 18        Shawn Mendes    canadian pop  2015  150    75    75  -7     5   76
# 19          Ed Sheeran             pop  2015   95    61    81  -7    64   85
# 20       Justin Bieber    canadian pop  2015   95    80    59  -5     8   43
# 21       Justin Bieber    canadian pop  2015  192    61    36  -7    18    8
# 22    Carly Rae Jepsen    canadian pop  2015  122    81    62  -5    22   60
# 23       Justin Bieber    canadian pop  2015  114    26    38  -9    17   52
# 24         Jess Glynne       dance pop  2015  120    82    57  -3    16   66
# 25        Gwen Stefani       dance pop  2015  120    80    88  -4    20   54
# 26        Shawn Mendes    canadian pop  2016  150    75    75  -7     5   76
# 27         Mike Posner       dance pop  2016  102    71    66  -7     8   69
# 28       Justin Bieber    canadian pop  2016   95    80    59  -5     8   43
# 29         Demi Lovato       dance pop  2016   87    74    63  -5    28   26
# 30        Shawn Mendes    canadian pop  2016  175    34    47  -6    10   27
# 31    Carly Rae Jepsen    canadian pop  2016  119    72    56  -6     5   25
# 32    Carly Rae Jepsen    canadian pop  2016  114    87    65  -5    37   44
# 33         Hilary Duff       dance pop  2016  124    76    57  -6     4   40
# 34       Janet Jackson       dance pop  2016  123    71    83  -7    31   83
# 35        Shawn Mendes    canadian pop  2017   83    82    44  -4    11   75
# 36        Shawn Mendes    canadian pop  2017  148    66    56  -5    11   36
# 37               Kesha       dance pop  2017   73    39    58  -7    11   32
# 38          Jonas Blue       dance pop  2017  104    79    74  -4     5   57
# 39             Cardi B             pop  2018  136    73    82  -4    37   65
# 40        Shawn Mendes    canadian pop  2018  122    81    87  -4     8   97
# 41         Troye Sivan       dance pop  2018  103    46    70  -8     5   48
# 42        Taylor Swift             pop  2018  160    84    58  -5    10   50
# 43             Cardi B             pop  2018  130    59    97  -8     8   27
# 44         Demi Lovato       dance pop  2018  102    77    58  -5     9   76
#
#     dur  acous  spch  pop    supergenre
# 0   230     33     4   73           pop
# 1   227      1     5   66           pop
# 2   185     47    27   58     dance pop
# 3   193     19     7   56           pop
# 4   223     15     6   75           pop
# 5   223      3    18   72           pop
# 6   265      0     6   61     dance pop
# 7   215     26     4   69     dance pop
# 8   227     29    11   68     dance pop
# 9   157      1     3   67           pop
# 10  173     59     4   85           pop
# 11  223      2     3   80     dance pop
# 12  219      6    17   78           pop
# 13  229     46     3   67           pop
# 14  169      7     6   50           pop
# 15  234     84    44   83  canadian pop
# 16  235      6     3   81           pop
# 17  201      8     5   81  canadian pop
# 18  207      2     7   78  canadian pop
# 19  220      1     7   74           pop
# 20  208     13     6   72  canadian pop
# 21  200      5    10   68  canadian pop
# 22  205      1     4   66  canadian pop
# 23  134     88     3   63  canadian pop
# 24  211      6     3   52     dance pop
# 25  202      8     6   39     dance pop
# 26  207      2     7   78  canadian pop
# 27  198      4    11   78     dance pop
# 28  208     13     6   72  canadian pop
# 29  194      0     4   65     dance pop
# 30  216     60     4   65  canadian pop
# 31  251      1     5   63  canadian pop
# 32  234      1     6   46  canadian pop
# 33  204      0     6   36     dance pop
# 34  250      5    18   31     dance pop
# 35  188     11    34   84  canadian pop
# 36  209     13     8   81  canadian pop
# 37  230     49     3   77     dance pop
# 38  184     10     4   75     dance pop
# 39  253     10    13   85           pop
# 40  199     38     6   84  canadian pop
# 41  205      0     8   76     dance pop
# 42  190     13    22   52           pop
# 43  264      5    26   45           pop
# 44  182      5     8   44     dance pop

# %% [markdown]
# Drop lines corresponding to the top 3 supergenres

# %%
print('before shape:', preprocessed_data.shape)
# Out:
# before shape: (582, 16)

# %%
supressed_data = preprocessed_data.copy()

drop_indexes = supressed_data[supressed_data.supergenre == 'dance pop'].index
supressed_data.drop(drop_indexes, inplace=True)

drop_indexes = supressed_data[supressed_data.supergenre == 'pop'].index
supressed_data.drop(drop_indexes, inplace=True)

drop_indexes = supressed_data[supressed_data.supergenre == 'canadian pop'].index
supressed_data.drop(drop_indexes, inplace=True)

# %%
print('shape after:', supressed_data.shape)
print('unique after:', supressed_data.supergenre.unique())
# Out:
# shape after: (128, 16)
# unique after: ['mellow' 'hip hop' 'barbadian pop' 'room' 'soul' 'band' 'complextro'
#  'house' 'electropop' 'dance' 'r&b' 'edm' 'latin']

# %%
merged_processed_data = pd.concat([supressed_data, maximum_data]).reset_index(drop=True)
print('shape merged (expected 128 + 45 lines):', merged_processed_data.shape)
merged_processed_data.head()
# Out:
# shape merged (expected 128 + 45 lines): (173, 16)
#    id                     title   artist            genre  year  bpm  nrgy  \
# 0   1          Hey, Soul Sister    Train       neo mellow  2010   97    89
# 1   2      Love The Way You Lie   Eminem  detroit hip hop  2010   87    93
# 2  10  Only Girl (In The World)  Rihanna    barbadian pop  2010  126    72
# 3  16     OMG (feat. will.i.am)    Usher      atl hip hop  2010  130    75
# 4  43                      Hard  Rihanna    barbadian pop  2010  182    75
#
#    dnce  dB  live  val  dur  acous  spch  pop     supergenre
# 0    67  -4     8   80  217     19     4   83         mellow
# 1    75  -5    52   64  263     24    23   82        hip hop
# 2    79  -4     7   61  235     13     4   73  barbadian pop
# 3    78  -6    36   33  269     20     3   72        hip hop
# 4    31  -4    65   16  251      1    11   57  barbadian pop

# %%
# analysing the final supergenre groups
merged_processed_data.groupby(by='supergenre', as_index=False)['title'].agg({'songs': 'count'}) \
        .sort_values('songs', ascending=False) \
        .reset_index(drop=True)
# Out:
#        supergenre  songs
# 0            band     15
# 1   barbadian pop     15
# 2    canadian pop     15
# 3       dance pop     15
# 4             pop     15
# 5         hip hop     14
# 6      electropop     13
# 7            room     12
# 8            soul     11
# 9             r&b     10
# 10         mellow      9
# 11            edm      7
# 12     complextro      6
# 13          dance      6
# 14          house      5
# 15          latin      5

# %% [markdown]
# ## Saving preprocessed file
#
# The new dataset is a subset of the original where the two following criteria were fulfilled.
#
# 1. Only genres with at least 5 songs will be allowed. 16 of the 29 supergenres passed this criterion.
# 2. For genres with more than 15 songs, only 15 will be chosen randomly. Those genres were `dance pop`, `pop` and `canadian pop`.

# %%
print('final shape:', merged_processed_data.shape)
merged_processed_data.head(3)
# Out:
# final shape: (173, 16)
#    id                     title   artist            genre  year  bpm  nrgy  \
# 0   1          Hey, Soul Sister    Train       neo mellow  2010   97    89
# 1   2      Love The Way You Lie   Eminem  detroit hip hop  2010   87    93
# 2  10  Only Girl (In The World)  Rihanna    barbadian pop  2010  126    72
#
#    dnce  dB  live  val  dur  acous  spch  pop     supergenre
# 0    67  -4     8   80  217     19     4   83         mellow
# 1    75  -5    52   64  263     24    23   82        hip hop
# 2    79  -4     7   61  235     13     4   73  barbadian pop

# %%
merged_processed_data.to_csv('data/002_intermediate_data/preprocessed_data.csv', index=False, encoding='latin-1')
